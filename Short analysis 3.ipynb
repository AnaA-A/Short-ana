# %%
#In order to get familiar with the data and do some basic analysis I will import pandas. 
import pandas as pd
import numpy as np

# %% [markdown]
# I downloaded the New York City Airbnb Open Data database on Kaggle and assigned the spreadsheet with the variable name a_dataframe.

# %%
a_dataframe = pd.read_csv("/Users/Lenovo/Desktop/AB_NYC_2019.csv")

# %%
a_dataframe
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
a_dataframe.shape
# Out:
# (48895, 16)

# %%
#I use the .head() command to get the first 5 rows of the DataFrame.
a_dataframe.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# WIth the .tail() command I can view the last 5 rows of the DataFrame.
a_dataframe.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
a_dataframe.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
columns_to_drop = ['id']

# %%
a_dataframe
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
inplace = True

# %%
a_dataframe["neighbourhood_group"].tail(10)
# Out:
# 48885    Manhattan
# 48886    Manhattan
# 48887     Brooklyn
# 48888    Manhattan
# 48889       Queens
# 48890     Brooklyn
# 48891     Brooklyn
# 48892    Manhattan
# 48893    Manhattan
# 48894    Manhattan
# Name: neighbourhood_group, dtype: object

# %%
a_dataframe[5:10]
# Out:
#      id                                       name  host_id  host_name  \
# 5  5099  Large Cozy 1 BR Apartment In Midtown East     7322      Chris
# 6  5121                            BlissArtsSpace!     7356      Garon
# 7  5178           Large Furnished Room Near B'way      8967   Shunichi
# 8  5203         Cozy Clean Guest Room - Family Apt     7490  MaryEllen
# 9  5238         Cute & Cozy Lower East Side 1 bdrm     7549        Ben
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 5           Manhattan         Murray Hill  40.74767  -73.97500
# 6            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8           Manhattan     Upper West Side  40.80178  -73.96723
# 9           Manhattan           Chinatown  40.71344  -73.99037
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 5  Entire home/apt    200               3                 74  2019-06-22
# ...

# %%
# Returns a list of booleans.
a_dataframe['price'] < 100
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 48890     True
# 48891     True
# 48892    False
# 48893     True
# 48894     True
# Name: price, Length: 48895, dtype: bool

# %%
# Returns a list with prices below 100.
a_dataframe[a_dataframe['price'] < 100]
# Out:
#              id                                               name    host_id  \
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# ...         ...                                                ...        ...
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
# Assigning a new variable showing only the apartments in the designated price range.
new_dataframe = a_dataframe[a_dataframe['price'] < 100]

# %%
new_dataframe.shape
# Out:
# (21877, 16)

# %%
new_dataframe.nlargest
# Out:
# <bound method DataFrame.nlargest of              id                                               name    host_id  \
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# ...         ...                                                ...        ...
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
# ...

# %%
# We extract 3 apartments with the most reviews per month.
a_dataframe.nlargest(3, 'reviews_per_month')
# Out:
#              id                                               name    host_id  \
# 42075  32678719  Enjoy great views of the City in our Deluxe Room!  244361589
# 42076  32678720           Great Room in the heart of Times Square!  244361589
# 38870  30423106                 Lou's Palace-So much for so little  228415932
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 42075   Row NYC           Manhattan  Theater District  40.75918  -73.98801
# 42076   Row NYC           Manhattan  Theater District  40.75828  -73.98876
# 38870    Louann              Queens          Rosedale  40.65417  -73.74158
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 42075  Private room    100               1                156  2019-07-07
# 42076  Private room    199               1                 82  2019-07-07
# 38870  Private room     45               1                 37  2019-07-08
#
# ...

# %%
a_dataframe.nlargest(3, ['reviews_per_month', 'number_of_reviews'])
# Out:
#              id                                               name    host_id  \
# 42075  32678719  Enjoy great views of the City in our Deluxe Room!  244361589
# 42076  32678720           Great Room in the heart of Times Square!  244361589
# 38870  30423106                 Lou's Palace-So much for so little  228415932
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 42075   Row NYC           Manhattan  Theater District  40.75918  -73.98801
# 42076   Row NYC           Manhattan  Theater District  40.75828  -73.98876
# 38870    Louann              Queens          Rosedale  40.65417  -73.74158
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 42075  Private room    100               1                156  2019-07-07
# 42076  Private room    199               1                 82  2019-07-07
# 38870  Private room     45               1                 37  2019-07-08
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as stats

# %%
sns.set_style('whitegrid')

# %%
a_dataframe.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
import scipy.stats as stats
sns.jointplot(x= 'price', y= 'number_of_reviews', data = a_dataframe).annotate(stats.pearsonr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22176\632430335.py in <module>
#       1 import scipy.stats as stats
# ----> 2 sns.jointplot(x= 'price', y= 'number_of_reviews', data = a_dataframe).annotate(stats.pearsonr)
#
# AttributeError: 'JointGrid' object has no attribute 'annotate'

# %%
sns.jointplot(x = 'price', y = 'number_of_reviews', data = a_dataframe , kind = 'scatter')

# %% [markdown]
# Based on the data it can be concluded that the number of reviews is proportional with the price of the rent per night.
